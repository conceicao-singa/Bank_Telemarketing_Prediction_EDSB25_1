# %%
import sys
import os
import pandas as pd

# Add the absolute path to the scripts folder
scripts_path = os.path.abspath("../scripts")
sys.path.append(scripts_path)

# Now import directly from the file
from data_prep import (
    clean_column_names,
    encode_target,
    split_features,
    create_actionable_df,
    remove_duplicates,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       7 sys.path.append(scripts_path)
#       9 # Now import directly from the file
# ---> 10 from data_prep import (
#      11     clean_column_names,
#      12     encode_target,
#      13     split_features,
#      14     create_actionable_df,
#      15     remove_duplicates,
#      16 )
#
# ImportError: cannot import name 'remove_duplicates' from 'data_prep' (c:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\scripts\data_prep.py)

# %%
df = pd.read_csv(r'C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\raw\bank-additional-full.csv', sep=';')
print(df.columns.tolist())
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
# Load raw data
df = pd.read_csv(
    r'C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\raw\bank-additional-full.csv',
    sep=';'
)
# Preprocessing
df = clean_column_names(df)
df = encode_target(df, target_col="y")

# Split features
X_act, X_bmk, y = split_features(df)

# Create actionable dataframe
df_act = create_actionable_df(X_act, y)

# Check results
print(df_act.shape)
df_act.head()
# Out:
# (39404, 20)
#          job  marital    education  default housing loan    contact month  \
# 0  housemaid  married     basic.4y       no      no   no  telephone   may
# 1   services  married  high.school  unknown      no   no  telephone   may
# 2   services  married  high.school       no     yes   no  telephone   may
# 3     admin.  married     basic.6y       no      no   no  telephone   may
# 4   services  married  high.school       no      no  yes  telephone   may
#
#   day_of_week     poutcome  age  campaign  pdays  previous  emp_var_rate  \
# 0         mon  nonexistent   56         1    999         0           1.1
# 1         mon  nonexistent   57         1    999         0           1.1
# 2         mon  nonexistent   37         1    999         0           1.1
# 3         mon  nonexistent   40         1    999         0           1.1
# 4         mon  nonexistent   56         1    999         0           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0

# %%
import data_prep as dp
print(dir(dp))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'clean_column_names', 'create_actionable_df', 'encode_target', 'pd', 'split_features']

# %%
remove_duplicates(df_act)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 remove_duplicates(df_act)
#
# NameError: name 'remove_duplicates' is not defined
