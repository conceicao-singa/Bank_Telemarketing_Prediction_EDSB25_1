# %%
import sys
import os
import pandas as pd

# Add the absolute path to the scripts folder
scripts_path = os.path.abspath("../scripts")
sys.path.append(scripts_path)

# Now import directly from the file
from data_prep import (
    clean_column_names,
    encode_target,
    split_features,
    create_actionable_df,
    remove_duplicates,
    add_age_group,
    add_housing_loan_interaction,
    impute_marital_unknown,
    transform_pdays,
    get_features_to_keep,  split_features_target,
    get_column_types,
    build_preprocessor,
    time_based_split,
    preprocess_data, 
    remove_outliers_iqr

)

from utils import save_processed_splits

# %%
df = pd.read_csv(r'C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\raw\bank-additional-full.csv', sep=';')
print(df.columns.tolist())
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
# Load raw data
df = pd.read_csv(
    r'C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\raw\bank-additional-full.csv',
    sep=';'
)
# Preprocessing
df = clean_column_names(df)
df = encode_target(df, target_col="y")

# Split features
X_act, X_bmk, y = split_features(df)

# Create actionable dataframe
df_act = create_actionable_df(X_act, y)

# Check results
print(df_act.shape)
df_act.head()
# Out:
# (39404, 20)
#          job  marital    education  default housing loan    contact month  \
# 0  housemaid  married     basic.4y       no      no   no  telephone   may
# 1   services  married  high.school  unknown      no   no  telephone   may
# 2   services  married  high.school       no     yes   no  telephone   may
# 3     admin.  married     basic.6y       no      no   no  telephone   may
# 4   services  married  high.school       no      no  yes  telephone   may
#
#   day_of_week     poutcome  age  campaign  pdays  previous  emp_var_rate  \
# 0         mon  nonexistent   56         1    999         0           1.1
# 1         mon  nonexistent   57         1    999         0           1.1
# 2         mon  nonexistent   37         1    999         0           1.1
# 3         mon  nonexistent   40         1    999         0           1.1
# 4         mon  nonexistent   56         1    999         0           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
import data_prep as dp
print(dir(dp))
# Out:
# ['ColumnTransformer', 'OneHotEncoder', 'StandardScaler', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add_age_group', 'add_housing_loan_interaction', 'build_preprocessor', 'clean_column_names', 'create_actionable_df', 'encode_target', 'get_column_types', 'get_features_to_keep', 'impute_marital_unknown', 'np', 'pd', 'preprocess_data', 'remove_duplicates', 'remove_outliers_iqr', 'split_features', 'split_features_target', 'time_based_split', 'transform_pdays']

# %%
remove_duplicates(df_act)
# Out:
# Duplicates removed: 0
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome  age  campaign  pdays  \
# ...

# %%
df_act = remove_outliers_iqr(df_act, 'campaign')
df_act = remove_outliers_iqr(df_act, 'age')
df_act = remove_outliers_iqr(df_act, 'cons_conf_idx')
# Out:
# campaign: Removed 691 outliers
# age: Removed 2 outliers
# cons_conf_idx: Removed 0 outliers

# %%
df_act["age"].describe()
# Out:
# count    38711.000000
# mean        40.102297
# std         10.464800
# min         17.000000
# 25%         32.000000
# 50%         38.000000
# 75%         47.000000
# max         95.000000
# Name: age, dtype: float64

# %%
add_age_group(df_act)
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome  ...  campaign  pdays  \
# ...

# %%
add_housing_loan_interaction(df_act)
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome  ...  pdays  previous  \
# ...

# %%
impute_marital_unknown(df_act)
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome  ...  pdays  previous  \
# ...

# %%
transform_pdays(df_act)
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome  ...  previous  emp_var_rate  \
# ...

# %%
# Feature engineering

features_to_keep = get_features_to_keep(df_act)
print("Features to keep:", features_to_keep)
# Out:
# Features to keep: ['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'age', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'age_group', 'housing_loan_interaction', 'pdays_cat']

# %%
df_clean = df_act.drop(columns=['nr_employed',"campaign", 'previous','poutcome','pdays_cat', 'cons_price_idx',"euribor3m","default"]).copy()

#df_clean = df_act.drop(columns=['nr_employed',"default",'campaign', 'previous','poutcome','pdays_cat', 'cons_conf_idx',"emp_var_rate","nr_employed"]).copy()

# %%
# 1. Split features and target
X, y = split_features_target(df_clean, target_col="y")

# 2. Identify column types
numerical_cols, categorical_cols = get_column_types(X)

# %%
# 3. Build preprocessor
preprocessor = build_preprocessor(numerical_cols, categorical_cols)

# 4. Time-based split
X_train, X_test, y_train, y_test = time_based_split(X, y, train_ratio=0.8)

X_test_unprocessed=X_test.copy()


# 5. Fit and transform
X_train_processed, X_test_processed = preprocess_data(X_train, X_test, preprocessor)
print("Train shape:", X_train_processed.shape, y_train.shape)
print("Test shape:", X_test_processed.shape, y_test.shape)
# Out:
# Train shape: (30968, 58) (30968,)
# Test shape: (7743, 58) (7743,)

# %%
save_processed_splits(
    X_train_processed,   # shape (30968, 61)
    y_train,             # shape (30968,)
    X_test_processed,    # shape (7743, 61)
    y_test,              # shape (7743,)
    preprocessor,
    r"C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\processed"
)
# Out:
# Processed splits saved to C:\Users\DELL\OneDrive\Data Science\Bank_Telemarketing_Prediction_EDSB25_1\data\processed

# %%
print("X_train_processed shape:", X_train_processed.shape)
print("X_test_processed shape:", X_test_processed.shape)
print("Feature names length:", len(preprocessor.get_feature_names_out()))
# Out:
# X_train_processed shape: (30968, 58)
# X_test_processed shape: (7743, 58)
# Feature names length: 58

# %%
# Save X_test_unprocessed into data/processed folder
X_test_unprocessed.to_csv("../data/interim/test_unprocessed.csv", index=False)

print("✅ Saved X_test_unprocessed to data/interim/test_unprocessed.csv")
# Out:
# ✅ Saved X_test_unprocessed to data/interim/test_unprocessed.csv

# %%
X_test_processed
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 107839 stored elements and shape (7743, 58)>
